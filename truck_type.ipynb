# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.8/898.8 kB 47.5 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/trucks/Truck_detection.v1i.yolov8
# !yolo task=detect mode=train model=yolov8n.pt data= data.yaml epochs=50 imgsz=640 plots=True
# Out:
# /content/drive/MyDrive/trucks/Truck_detection.v1i.yolov8
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 207MB/s]
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !pip install Pillow
from PIL import Image
from IPython.display import display

img = Image.open('/content/drive/MyDrive/trucks/Truck_detection.v1i.yolov8/runs/detect/train/val_batch0_labels.jpg')
img = img.resize((600, 400))
display(img)
# Out:
# ...
# <PIL.Image.Image image mode=RGB size=600x400>

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/trucks/Truck_detection.v1i.yolov8/valid/labels.cache... 39 images, 0 backgrounds, 0 corrupt: 100% 39/39 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:03<00:00,  1.12s/it]
#                    all         39         44      0.321       0.63      0.446      0.289
#                   HCVs         15         16       0.48       0.75      0.602      0.366
#                   LCVs          1          1      0.169      0.844      0.199      0.179
#                   MAVs          6          6       0.32      0.667      0.551      0.362
#                   MCVs         14         18       0.47      0.556      0.418      0.253
#                 Tanker          3          3      0.167      0.333      0.459      0.284
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/trucks/Truck_detection.v1i.yolov8/test/images
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/19 /content/drive/MyDrive/trucks/Truck_detection.v1i.yolov8/test/images/Datacluster-Truck-1-_jpg.rf.a2ecc94fd8f6ae96c5cd24ffa08dfb92.jpg: 640x640 1 HCVs, 8.5ms
# image 2/19 /content/drive/MyDrive/trucks/Truck_detection.v1i.yolov8/test/images/Datacluster-Truck-106-_jpg.rf.7b2fd8185dadabb676c476c1719e4816.jpg: 640x640 1 HCVs, 7.7ms
# image 3/19 /content/drive/MyDrive/trucks/Truck_detection.v1i.yolov8/test/images/Datacluster-Truck-107-_jpg.rf.5109e2fc4ab784efe65f957a76016715.jpg: 640x640 1 MCVs, 7.6ms
# image 4/19 /content/drive/MyDrive/trucks/Truck_detection.v1i.yolov8/test/images/Datacluster-Truck-118-_jpg.rf.9b8be3864a4ce0464be132ab4913b970.jpg: 640x640 1 LCVs, 13.7ms
# ...
